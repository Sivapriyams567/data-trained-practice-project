# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('myexcel - myexcel.csv.csv')
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
# 457             Kansas   947276.0
#
# [458 rows x 9 columns]

# %%
data.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
x = data['Salary'].mean()
data['Salary'].fillna(x,inplace = True)
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# 1            Marquette  6.796117e+06
# 2    Boston University  4.833970e+06
# 3        Georgia State  1.148640e+06
# 4                  NaN  5.000000e+06
# ..                 ...           ...
# 453             Butler  2.433333e+06
# 454                NaN  9.000000e+05
# 455                NaN  2.900000e+06
# 456             Kansas  9.472760e+05
# 457             Kansas  9.472760e+05
#
# [458 rows x 9 columns]

# %%
data.drop_duplicates(inplace = True)
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# 1            Marquette  6.796117e+06
# 2    Boston University  4.833970e+06
# 3        Georgia State  1.148640e+06
# 4                  NaN  5.000000e+06
# ..                 ...           ...
# 453             Butler  2.433333e+06
# 454                NaN  9.000000e+05
# 455                NaN  2.900000e+06
# 456             Kansas  9.472760e+05
# 457             Kansas  9.472760e+05
#
# [458 rows x 9 columns]

# %%
data.dropna ( inplace = True)

# %%
data.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
data['Height'] = np.random.uniform(150,180,size = len(data))

# %%
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  172.179292     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  150.022074     235
# 2     John Holland  Boston Celtics      30       SG   27  175.520048     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  170.972505     185
# 6    Jordan Mickey  Boston Celtics      55       PF   21  167.617095     235
# ..             ...             ...     ...      ...  ...         ...     ...
# 451  Chris Johnson       Utah Jazz      23       SF   26  156.298564     206
# 452     Trey Lyles       Utah Jazz      41       PF   20  172.559448     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  153.611942     203
# 456    Jeff Withey       Utah Jazz      24        C   26  174.759266     231
# 457       Priyanka       Utah Jazz      34        C   25  167.612747     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# 1            Marquette  6.796117e+06
# 2    Boston University  4.833970e+06
# 3        Georgia State  1.148640e+06
# 6                  LSU  1.170960e+06
# ..                 ...           ...
# 451             Dayton  9.813480e+05
# 452           Kentucky  2.239800e+06
# 453             Butler  2.433333e+06
# 456             Kansas  9.472760e+05
# 457             Kansas  9.472760e+05
#
# [374 rows x 9 columns]

# %% [markdown]
# #####  How Many Are There In Each Team and Precentage splitting with respect to the total employees.

# %% [markdown]
# ##### total no of employees in each team:

# %%
data['Team'].value_counts()
# Out:
# Memphis Grizzlies         17
# New Orleans Pelicans      16
# Portland Trail Blazers    15
# Philadelphia 76ers        15
# Detroit Pistons           15
# Milwaukee Bucks           14
# Oklahoma City Thunder     14
# Los Angeles Clippers      14
# Boston Celtics            13
# Washington Wizards        13
# Charlotte Hornets         13
# Phoenix Suns              13
# Sacramento Kings          13
# Brooklyn Nets             13
# Dallas Mavericks          12
# Indiana Pacers            12
# Cleveland Cavaliers       12
# Chicago Bulls             12
# Los Angeles Lakers        12
# Golden State Warriors     12
# Houston Rockets           11
# San Antonio Spurs         11
# Atlanta Hawks             11
# Miami Heat                11
# New York Knicks           11
# Utah Jazz                 11
# Orlando Magic             10
# Toronto Raptors           10
# Denver Nuggets             9
# Minnesota Timberwolves     9
# Name: Team, dtype: int64

# %% [markdown]
# ###### Precentage splitting with respect to the total employees:

# %%
data['Team'].value_counts()/len(data)*100
# Out:
# Memphis Grizzlies         4.545455
# New Orleans Pelicans      4.278075
# Portland Trail Blazers    4.010695
# Philadelphia 76ers        4.010695
# Detroit Pistons           4.010695
# Milwaukee Bucks           3.743316
# Oklahoma City Thunder     3.743316
# Los Angeles Clippers      3.743316
# Boston Celtics            3.475936
# Washington Wizards        3.475936
# Charlotte Hornets         3.475936
# Phoenix Suns              3.475936
# Sacramento Kings          3.475936
# Brooklyn Nets             3.475936
# Dallas Mavericks          3.208556
# Indiana Pacers            3.208556
# Cleveland Cavaliers       3.208556
# Chicago Bulls             3.208556
# Los Angeles Lakers        3.208556
# Golden State Warriors     3.208556
# Houston Rockets           2.941176
# San Antonio Spurs         2.941176
# Atlanta Hawks             2.941176
# Miami Heat                2.941176
# New York Knicks           2.941176
# Utah Jazz                 2.941176
# Orlando Magic             2.673797
# Toronto Raptors           2.673797
# Denver Nuggets            2.406417
# Minnesota Timberwolves    2.406417
# Name: Team, dtype: float64

# %% [markdown]
# ###### Segregate the employees w.r.t different positions.

# %%
employees = data.groupby('Position')['Name'].apply(list)
for Position, Names in employees.items():
    print(f"employees in {Position} position:")
    for name in Names:
     print(name)
    print("\n")
# Out:
# employees in C position:
# Kelly Olynyk
# Jared Sullinger
# Tyler Zeller
# Brook Lopez
# Henry Sims
# Robin Lopez
# Joel Embiid
# Jahlil Okafor
# Andrew Bogut
# Festus Ezeli
# Marreese Speights
# Cole Aldrich
# DeAndre Jordan
# Tarik Black
# Roy Hibbert
# Robert Sacre
# Alex Len
# Alan Williams
# Willie Cauley-Stein
# DeMarcus Cousins
# Kosta Koufos
# Joakim Noah
# Sasha Kaun
# Tristan Thompson
# Joel Anthony
# Aron Baynes
# Andre Drummond
# Jordan Hill
# Greg Monroe
# Miles Plumlee
# JaVale McGee
# Matt Bonner
# Tim Duncan
# Al Horford
# Frank Kaminsky III
# Cody Zeller
# Hassan Whiteside
# Dewayne Dedmon
# Nikola Vucevic
# JJ Hickson
# Gorgui Dieng
# Karl-Anthony Towns
# Steven Adams
# Enes Kanter
# Nazr Mohammed
# Ed Davis
# Chris Kaman
# Mason Plumlee
# Kyle Korver
# Lamar Patterson
# Troy Daniels
# Aaron Harrison
# Jeremy Lamb
# Courtney Lee
# Tyler Johnson
# Josh Richardson
# Dwyane Wade
# Victor Oladipo
# Alan Anderson
# Bradley Beal
# Jarell Eddie
# Garrett Temple
# Gary Harris
# Mike Miller
# JaKarr Sampson
# Andrew Wiggins
# Randy Foye
# Anthony Morrow
# Andre Roberson
# Dion Waiters
# Pat Connaughton
# Allen Crabbe
# Gerald Henderson
# C.J. McCollum
# Luis Montero
# Alec Burks
# Rodney Hood

# %% [markdown]
# ##### Find from which age group most of the employees belong to.

# %%
data['Age Group'] = data['Age'].apply(lambda age:'20-25' if 20 <= age <= 25 else ('26-30' if 26 <= age <= 30 else ('31-35' if 31 <= age <= 35 else '36 and above')))

data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  172.179292     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  150.022074     235
# 2     John Holland  Boston Celtics      30       SG   27  175.520048     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  170.972505     185
# 6    Jordan Mickey  Boston Celtics      55       PF   21  167.617095     235
# ..             ...             ...     ...      ...  ...         ...     ...
# 451  Chris Johnson       Utah Jazz      23       SF   26  156.298564     206
# 452     Trey Lyles       Utah Jazz      41       PF   20  172.559448     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  153.611942     203
# 456    Jeff Withey       Utah Jazz      24        C   26  174.759266     231
# 457       Priyanka       Utah Jazz      34        C   25  167.612747     231
#
#                College        Salary Age Group
# 0                Texas  7.730337e+06     20-25
# 1            Marquette  6.796117e+06     20-25
# 2    Boston University  4.833970e+06     26-30
# 3        Georgia State  1.148640e+06     20-25
# 6                  LSU  1.170960e+06     20-25
# ..                 ...           ...       ...
# 451             Dayton  9.813480e+05     26-30
# 452           Kentucky  2.239800e+06     20-25
# 453             Butler  2.433333e+06     26-30
# 456             Kansas  9.472760e+05     26-30
# 457             Kansas  9.472760e+05     20-25
#
# [374 rows x 10 columns]

# %%
data['Age Group'].value_counts()
# Out:
# 20-25           172
# 26-30           134
# 31-35            49
# 36 and above     19
# Name: Age Group, dtype: int64

# %% [markdown]
# ######

# %% [markdown]
# ##### Find out under which team and position, spending in terms of salary is high.

# %%
spending_salary = data.groupby(['Team','Position'])['Salary'].sum()
spending_salary.idxmax()
# Out:
# ('Miami Heat', 'PF')

# %% [markdown]
# ###### Find if there is any correlation between age and salary , represent it visually.

# %%
correlation = data['Age'].corr(data['Salary'])

print("THE CORRELATION BTW AGE AND SALARY IS:",correlation)
# Out:
# THE CORRELATION BTW AGE AND SALARY IS: 0.15775114505522586

# %%
sns.scatterplot(x="Salary" ,y= "Age",data= data)
plt.ylabel("age")
plt.xlabel("salary")
plt.title("correlation btw age and salary")
plt.show()
